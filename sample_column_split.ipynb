# %%
import pandas as pd

# %%
df = pd.read_csv('sample.csv')

# %%
df
# Out:
#       Unnamed: 0 channelGrouping      date  \
# 0              0  Organic Search  20160902
# 1              1  Organic Search  20160902
# 2              2  Organic Search  20160902
# 3              3  Organic Search  20160902
# 4              4  Organic Search  20160902
# 5              5  Organic Search  20160902
# 6              6  Organic Search  20160902
# 7              7  Organic Search  20160902
# 8              8  Organic Search  20160902
# 9              9  Organic Search  20160902
# 10            10  Organic Search  20160902
# 11            11  Organic Search  20160902
# 12            12  Organic Search  20160902
# 13            13  Organic Search  20160902
# 14            14  Organic Search  20160902
# 15            15  Organic Search  20160902
# 16            16  Organic Search  20160902
# 17            17  Organic Search  20160902
# 18            18  Organic Search  20160902
# 19            19  Organic Search  20160902
# 20            20  Organic Search  20160902
# ...

# %%
df['device'][0]
# Out:
# '{"browser": "Chrome", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Windows", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}'

# %%
df['device'][0].split(',')[0].split('"')[-2]
# Out:
# 'Chrome'

# %%
df['device'][0].split(',')
# Out:
# ['{"browser": "Chrome"',
#  ' "browserVersion": "not available in demo dataset"',
#  ' "browserSize": "not available in demo dataset"',
#  ' "operatingSystem": "Windows"',
#  ' "operatingSystemVersion": "not available in demo dataset"',
#  ' "isMobile": false',
#  ' "mobileDeviceBranding": "not available in demo dataset"',
#  ' "mobileDeviceModel": "not available in demo dataset"',
#  ' "mobileInputSelector": "not available in demo dataset"',
#  ' "mobileDeviceInfo": "not available in demo dataset"',
#  ' "mobileDeviceMarketingName": "not available in demo dataset"',
#  ' "flashVersion": "not available in demo dataset"',
#  ' "language": "not available in demo dataset"',
#  ' "screenColors": "not available in demo dataset"',
#  ' "screenResolution": "not available in demo dataset"',
#  ' "deviceCategory": "desktop"}']

# %%
#creating new columns from device column
df['browser'] = df['device'].apply(lambda x: x.split(',')[0].split('"')[-2])
df['browserVersion'] = df['device'].apply(lambda x: x.split(',')[1].split('"')[-2])
df['browserSize'] = df['device'].apply(lambda x: x.split(',')[2].split('"')[-2])
df['operatingSystem'] = df['device'].apply(lambda x: x.split(',')[3].split('"')[-2])
df['operatingSystemVersion'] = df['device'].apply(lambda x: x.split(',')[4].split('"')[-2])
df['isMobile'] = df['device'].apply(lambda x: x.split(',')[5].split('"')[-2])
df['mobileDeviceBranding'] = df['device'].apply(lambda x: x.split(',')[6].split('"')[-2])
df['mobileDeviceModel'] = df['device'].apply(lambda x: x.split(',')[7].split('"')[-2])
df['mobileInputSelector'] = df['device'].apply(lambda x: x.split(',')[8].split('"')[-2])
df['mobileDeviceInfo'] = df['device'].apply(lambda x: x.split(',')[9].split('"')[-2])
df['mobileDeviceMarketingName'] = df['device'].apply(lambda x: x.split(',')[10].split('"')[-2])
df['flashVersion'] = df['device'].apply(lambda x: x.split(',')[11].split('"')[-2])
df['language'] = df['device'].apply(lambda x: x.split(',')[12].split('"')[-2])
df['screenColors'] = df['device'].apply(lambda x: x.split(',')[13].split('"')[-2])
df['screenResolution'] = df['device'].apply(lambda x: x.split(',')[14].split('"')[-2])
df['deviceCategory'] = df['device'].apply(lambda x: x.split(',')[15].split('"')[-2])

# %%
df.mobileDeviceBranding.value_counts()
# Out:
# not available in demo dataset    10000
# Name: mobileDeviceBranding, dtype: int64

# %%
df.browser.value_counts()
# Out:
# Chrome                      6917
# Safari                      1813
# Firefox                      464
# Internet Explorer            253
# Edge                         134
# Android Webview              112
# Opera                         90
# Opera Mini                    78
# Safari (in-app)               53
# YaBrowser                     23
# UC Browser                    20
# Coc Coc                        9
# Amazon Silk                    8
# Android Browser                8
# Mozilla Compatible Agent       4
# MRCHROME                       4
# BlackBerry                     4
# Nokia Browser                  2
# ADM                            1
# Puffin                         1
# Nintendo Browser               1
# Maxthon                        1
# Name: browser, dtype: int64

# %%
df.totals.value_counts()
#4167 people only ever visited once?
#what does newVisits mean?
# Out:
# {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1"}      4167
# {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1"}                        1093
# {"visits": "1", "hits": "2", "pageviews": "2", "newVisits": "1"}                      1041
# {"visits": "1", "hits": "3", "pageviews": "3", "newVisits": "1"}                       571
# {"visits": "1", "hits": "2", "pageviews": "2"}                                         268
# {"visits": "1", "hits": "4", "pageviews": "4", "newVisits": "1"}                       252
# {"visits": "1", "hits": "3", "pageviews": "3"}                                         190
# {"visits": "1", "hits": "5", "pageviews": "5", "newVisits": "1"}                       149
# {"visits": "1", "hits": "6", "pageviews": "6", "newVisits": "1"}                       106
# {"visits": "1", "hits": "3", "pageviews": "2", "newVisits": "1"}                        85
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 channelGrouping      date  \
# 0           0  Organic Search  20160902
# 1           1  Organic Search  20160902
# 2           2  Organic Search  20160902
# 3           3  Organic Search  20160902
# 4           4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# ...

# %%
df['mobileDeviceBranding'].value_counts()
# Out:
# not available in demo dataset    10000
# Name: mobileDeviceBranding, dtype: int64

# %%
df.geoNetwork[0].split(',')
# Out:
# ['{"continent": "Asia"',
#  ' "subContinent": "Western Asia"',
#  ' "country": "Turkey"',
#  ' "region": "Izmir"',
#  ' "metro": "(not set)"',
#  ' "city": "Izmir"',
#  ' "cityId": "not available in demo dataset"',
#  ' "networkDomain": "ttnet.com.tr"',
#  ' "latitude": "not available in demo dataset"',
#  ' "longitude": "not available in demo dataset"',
#  ' "networkLocation": "not available in demo dataset"}']

# %%
df.geoNetwork[0].split(',')[0].split('"')[-2]
# Out:
# 'Asia'

# %%
#creating new columns from geoNetwork column
df['continent'] = df['geoNetwork'].apply(lambda x: x.split(',')[0].split('"')[-2])
df['subContinent'] = df['geoNetwork'].apply(lambda x: x.split(',')[1].split('"')[-2])
df['country'] = df['geoNetwork'].apply(lambda x: x.split(',')[2].split('"')[-2])
df['region'] = df['geoNetwork'].apply(lambda x: x.split(',')[3].split('"')[-2])
df['metro'] = df['geoNetwork'].apply(lambda x: x.split(',')[4].split('"')[-2])
df['city'] = df['geoNetwork'].apply(lambda x: x.split(',')[5].split('"')[-2])
df['cityId'] = df['geoNetwork'].apply(lambda x: x.split(',')[6].split('"')[-2])
df['networkDomain'] = df['geoNetwork'].apply(lambda x: x.split(',')[7].split('"')[-2])
df['latitude'] = df['geoNetwork'].apply(lambda x: x.split(',')[8].split('"')[-2])
df['longitude'] = df['geoNetwork'].apply(lambda x: x.split(',')[9].split('"')[-2])
df['networkLocation'] = df['geoNetwork'].apply(lambda x: x.split(',')[10].split('"')[-2])

# %%
df.head()
# Out:
#    Unnamed: 0 channelGrouping      date  \
# 0           0  Organic Search  20160902
# 1           1  Organic Search  20160902
# 2           2  Organic Search  20160902
# 3           3  Organic Search  20160902
# 4           4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# ...

# %%
df.country.value_counts()
# Out:
# United States             4274
# India                      531
# United Kingdom             405
# Canada                     307
# Germany                    274
# Japan                      229
# Turkey                     212
# France                     210
# Brazil                     180
# Czechia                    158
# Mexico                     154
# Spain                      151
# Australia                  142
# Russia                     129
# Italy                      126
# Netherlands                123
# Taiwan                     116
# Thailand                   115
# Poland                     112
# Malaysia                    94
# Indonesia                   90
# Peru                        83
# Singapore                   77
# Philippines                 75
# Vietnam                     74
# Ireland                     69
# Israel                      64
# Argentina                   58
# Belgium                     55
# Ukraine                     55
# ...

# %%
df.city.value_counts()
# Out:
# not available in demo dataset    5941
# Mountain View                     493
# (not set)                         311
# New York                          274
# San Francisco                     226
# Sunnyvale                         125
# London                            122
# Los Angeles                       121
# San Jose                          110
# Istanbul                           74
# Toronto                            72
# Columbus                           69
# Seattle                            67
# Chicago                            65
# Bengaluru                          59
# Santa Clara                        57
# Bangkok                            57
# Sydney                             55
# Paris                              53
# Dublin                             49
# Prague                             46
# Sao Paulo                          44
# Warsaw                             44
# La Victoria                        42
# Madrid                             41
# ...
